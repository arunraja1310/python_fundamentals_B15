# %%
bikes=['splendor','rx100','rx135','passionPRO','acess125']
for x in bikes:
    if x=='splendor':
        print(x.upper())
    else:
        print(x.title())
# Out:
# SPLENDOR
# Rx100
# Rx135
# Passionpro
# Acess125

# %%
message=input("enter your favorite bike name")
for bike in bikes:
    if bike==message:
        print(f'your favorite {message} is available')
    else:
        print('your favorite bike not in our discount list')
# Out:
# enter your favorite bike namesplendor
# your favorite splendor is available
# your favorite bike not in our discount list
# your favorite bike not in our discount list
# your favorite bike not in our discount list
# your favorite bike not in our discount list

# %%
calc=input('3+5=')
if(int(calc)==8):
    print('your answer is correct')
else:
    print("your answer is incorrect")
# Out:
# 3+5=8
# your answer is correct
