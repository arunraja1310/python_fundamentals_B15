# %%
items=['paste','brush','bucket',1,2,3]
print(items)
# Out:
# ['paste', 'brush', 'bucket', 1, 2, 3]

# %%
len(items)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4bbc9a95c99b> in <module>
# ----> 1 len(items)
#
# NameError: name 'items' is not defined

# %%
print(items.pop())
# Out:
# 3

# %%
print(items.pop())
# Out:
# 2

# %%
print(items.pop())
# Out:
# 1

# %%
len(items)
# Out:
# 3

# %%
print(sorted(items))
# Out:
# ['brush', 'bucket', 'paste']

# %%
items.append('mug')
print(items)
# Out:
# ['paste', 'brush', 'bucket', 'mug']

# %%
print(sorted(items))
# Out:
# ['brush', 'bucket', 'mug', 'paste']

# %%
print(items.sort())
# Out:
# None

# %%
items.sort()

# %%
print(items)
# Out:
# ['brush', 'bucket', 'mug', 'paste']

# %%
print(items.append('apple pealer'))
# Out:
# None

# %%
print(items)
# Out:
# ['brush', 'bucket', 'mug', 'paste', 'apple pealer']

# %%
print(sorted(items))
# Out:
# ['apple pealer', 'brush', 'bucket', 'mug', 'paste']
