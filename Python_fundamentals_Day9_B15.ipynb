# %%
my_dict = {'name':'Jack', 'age': 26}
print(my_dict['name'])
# Out:
# Jack

# %%
print(my_dict.get('age'))
# Out:
# 26

# %%
my_dict['education']='engg'
print(my_dict)
# Out:
# {'name': 'Jack', 'age': 26, 'education': 'engg'}

# %%
print(my_dict.items())
# Out:
# dict_items([('name', 'Jack'), ('age', 26), ('education', 'engg')])

# %%
print(my_dict.keys())
# Out:
# dict_keys(['name', 'age', 'education'])
