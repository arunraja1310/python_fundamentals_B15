# %%
#1.Declare a String
My_String='Python Prog'
print(My_String)
# Out:
# Python Prog

# %%
#2.String declaration with different quotes;
My_String1='python fundamentals'
My_String2="String datatypes"
My_String3="""Triple Quotes"""
print(My_String1)
print(My_String2)
print(My_String3)
# Out:
# python fundamentals
# String datatypes
# Triple Quotes

# %%
My_String1.title() #3.used to show first letter of string capital.
# Out:
# 'Python Fundamentals'

# %%
My_String1.upper() #4.used to show all the letters to Capital case.
# Out:
# 'PYTHON FUNDAMENTALS'

# %%
My_String1.lower() #5.used to show all the letters to Lower case.
# Out:
# 'python fundamentals'
